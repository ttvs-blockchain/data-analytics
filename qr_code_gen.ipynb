# %% [markdown]
# # QR Code Genearation Time Analysis

# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics

# %%
# read csv
df = pd.read_csv("data/qr_code_gen.csv")
print(df)
# Out:
#    test_0_0  test_0_1  test_1_0  test_1_1  test_2_0  test_2_1
# 0      80.0     128.2      32.7      67.5      22.1      32.0
# 1      63.2     124.8      33.1      55.5      24.8      47.6
# 2      83.0     134.9      23.0      68.4      23.8      48.6
# 3      81.6     123.7      31.1      68.9      24.1      53.3
# 4      85.6     128.7      33.6      65.6      23.6      56.9
# 5      75.4     126.1      35.5      68.0      26.4      46.5
# 6      50.8     105.6      31.0      63.0      23.7      49.2
# 7      71.0     126.8      32.3      60.1      23.5      48.1
# 8      57.8     125.8      33.0      66.8      24.4      48.1
# 9      74.0     125.6      23.0      64.4      24.7      46.5

# %%
# data for Huawei P8 Personal Info QR Code Generation
personal_huawei_p8 = df["test_0_0"]
# data for Huawei P8 Certificate Info QR Code Generation
certificate_huawei_p8 = df["test_0_1"]
# data for iPhone 8 Personal Info QR Code Generation
personal_iphone8 = df["test_1_0"]
# data for iPhone 8 Certificate Info QR Code Generation
certificate_iphone8 = df["test_1_1"]
# data for iPhone 12 Mini Personal Info QR Code Generation
personal_iphone12_mini = df["test_2_0"]
# data for iPhone 12 Mini Certificate Info QR Code Generation
certificate_iphone12_mini = df["test_2_1"]

# %%
# plot Huawei P8 Personal Info QR Code Generation
fig, ax = plt.subplots()

bars = ax.bar(
    x=np.arange(personal_huawei_p8.size), 
    height=personal_huawei_p8,
    tick_label=personal_huawei_p8.index+1,
    color='blue',
    width=0.6
)
ax.axhline(personal_huawei_p8.mean(), color='red', linewidth=2)
ax.text(-1, 73, "avg = 72.2", color='red', weight='bold')
print('Mean:', personal_huawei_p8.mean())
print('SD:', statistics.stdev(personal_huawei_p8))


# Axis formatting.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Grab the color of the bars so we can make the
# text the same color.
bar_color = bars[0].get_facecolor()

# Add text annotations to the top of the bars.
# Note, you'll have to adjust this slightly (the 0.3)
# with different data.
for bar in bars:
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.3,
        round(bar.get_height(), 1),
        horizontalalignment='center',
        color='black',
        weight='bold'
    )

# set axis range
ax.set_ylim(40, 90)

# Add labels
ax.set_xlabel('Number of Samples', labelpad=15, color='#333333')
ax.set_ylabel('Frame Generation Time (millisecond)', labelpad=15, color='#333333')

fig.tight_layout()
# Out:
# Mean: 72.23999999999998
# SD: 11.578831259385955

# %%
# save figure
fig.savefig('mobile_app_analytics/huawei_p8_personal_info_qr_code_gen.png', dpi=600)

# %%
# plot Huawei P8 Certificate Info QR Code Generation
fig, ax = plt.subplots()

bars = ax.bar(
    x=np.arange(certificate_huawei_p8.size), 
    height=certificate_huawei_p8,
    tick_label=certificate_huawei_p8.index+1,
    color='blue',
    width=0.6
)
ax.axhline(certificate_huawei_p8.mean(), color='red', linewidth=2)
ax.text(-1, 122.5, "avg = 125.0", color='red', weight='bold')
print('Mean:', certificate_huawei_p8.mean())
print('SD:', statistics.stdev(certificate_huawei_p8))


# Axis formatting.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Grab the color of the bars so we can make the
# text the same color.
bar_color = bars[0].get_facecolor()

# Add text annotations to the top of the bars.
# Note, you'll have to adjust this slightly (the 0.3)
# with different data.
for bar in bars:
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.3,
        round(bar.get_height(), 1),
        horizontalalignment='center',
        color='black',
        weight='bold'
    )

# set axis range
ax.set_ylim(100, 150)

# Add labels
ax.set_xlabel('Number of Samples', labelpad=15, color='#333333')
ax.set_ylabel('Frame Generation Time (millisecond)', labelpad=15, color='#333333')

fig.tight_layout()
# Out:
# Mean: 125.01999999999998
# SD: 7.494264473582448

# %%
# save figure
fig.savefig('mobile_app_analytics/huawei_p8_cert_info_qr_code_gen.png', dpi=600)

# %%
# plot iPhone 8 Personal Info QR Code Generation
fig, ax = plt.subplots()

bars = ax.bar(
    x=np.arange(personal_iphone8.size), 
    height=personal_iphone8,
    tick_label=personal_iphone8.index+1,
    color='blue',
    width=0.6
)
ax.axhline(personal_iphone8.mean(), color='red', linewidth=2)
ax.text(-1, 28.5, "avg = 30.8", color='red', weight='bold')
print('Mean:', personal_iphone8.mean())
print('SD:', statistics.stdev(personal_iphone8))


# Axis formatting.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Grab the color of the bars so we can make the
# text the same color.
bar_color = bars[0].get_facecolor()

# Add text annotations to the top of the bars.
# Note, you'll have to adjust this slightly (the 0.3)
# with different data.
for bar in bars:
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.3,
        round(bar.get_height(), 1),
        horizontalalignment='center',
        color='black',
        weight='bold'
    )

# set axis range
ax.set_ylim(0, 50)

# Add labels
ax.set_xlabel('Number of Samples', labelpad=15, color='#333333')
ax.set_ylabel('Frame Generation Time (millisecond)', labelpad=15, color='#333333')

fig.tight_layout()
# Out:
# Mean: 30.830000000000002
# SD: 4.316904755338792

# %%
# save figure
fig.savefig('mobile_app_analytics/iphone8_personal_info_qr_code_gen.png', dpi=600)

# %%
# plot iPhone 8 Certificate Info QR Code Generation
fig, ax = plt.subplots()

bars = ax.bar(
    x=np.arange(certificate_iphone8.size), 
    height=certificate_iphone8,
    tick_label=certificate_iphone8.index+1,
    color='blue',
    width=0.6
)
ax.axhline(certificate_iphone8.mean(), color='red', linewidth=2)
ax.text(-1, 63, "avg = 64.8", color='red', weight='bold')
print('Mean:', certificate_iphone8.mean())
print('SD:', statistics.stdev(certificate_iphone8))


# Axis formatting.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Grab the color of the bars so we can make the
# text the same color.
bar_color = bars[0].get_facecolor()

# Add text annotations to the top of the bars.
# Note, you'll have to adjust this slightly (the 0.3)
# with different data.
for bar in bars:
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.3,
        round(bar.get_height(), 1),
        horizontalalignment='center',
        color='black',
        weight='bold'
    )

# set axis range
ax.set_ylim(30, 80)

# Add labels
ax.set_xlabel('Number of Samples', labelpad=15, color='#333333')
ax.set_ylabel('Frame Generation Time (millisecond)', labelpad=15, color='#333333')

fig.tight_layout()
# Out:
# Mean: 64.82
# SD: 4.2676561352678

# %%
# save figure
fig.savefig('mobile_app_analytics/iphone8_cert_info_qr_code_gen.png', dpi=600)

# %%
# plot iPhone 12 Mini Personal Info QR Code Generation
fig, ax = plt.subplots()

bars = ax.bar(
    x=np.arange(personal_iphone12_mini.size), 
    height=personal_iphone12_mini,
    tick_label=personal_iphone12_mini.index+1,
    color='blue',
    width=0.6
)
ax.axhline(personal_iphone12_mini.mean(), color='red', linewidth=2)
ax.text(-1, 26.5, "avg = 24.1", color='red', weight='bold')
print('Mean:', personal_iphone12_mini.mean())
print('SD:', statistics.stdev(personal_iphone12_mini))


# Axis formatting.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Grab the color of the bars so we can make the
# text the same color.
bar_color = bars[0].get_facecolor()

# Add text annotations to the top of the bars.
# Note, you'll have to adjust this slightly (the 0.3)
# with different data.
for bar in bars:
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.3,
        round(bar.get_height(), 1),
        horizontalalignment='center',
        color='black',
        weight='bold'
    )

# set axis range
ax.set_ylim(0, 50)

# Add labels
ax.set_xlabel('Number of Samples', labelpad=15, color='#333333')
ax.set_ylabel('Frame Generation Time (millisecond)', labelpad=15, color='#333333')

fig.tight_layout()
# Out:
# Mean: 24.11
# SD: 1.1100050049937205

# %%
# save figure
fig.savefig('mobile_app_analytics/iphone12_mini_personal_info_qr_code_gen.png', dpi=600)

# %%
# plot iPhone 12 Mini Certificate Info QR Code Generation
fig, ax = plt.subplots()

bars = ax.bar(
    x=np.arange(certificate_iphone12_mini.size), 
    height=certificate_iphone12_mini,
    tick_label=certificate_iphone12_mini.index+1,
    color='blue',
    width=0.6
)
ax.axhline(certificate_iphone12_mini.mean(), color='red', linewidth=2)
ax.text(-1, 45, "avg = 47.7", color='red', weight='bold')
print('Mean:', certificate_iphone12_mini.mean())
print('SD:', statistics.stdev(certificate_iphone12_mini))


# Axis formatting.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Grab the color of the bars so we can make the
# text the same color.
bar_color = bars[0].get_facecolor()

# Add text annotations to the top of the bars.
# Note, you'll have to adjust this slightly (the 0.3)
# with different data.
for bar in bars:
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.3,
        round(bar.get_height(), 1),
        horizontalalignment='center',
        color='black',
        weight='bold'
    )

# set axis range
ax.set_ylim(20, 70)

# Add labels
ax.set_xlabel('Number of Samples', labelpad=15, color='#333333')
ax.set_ylabel('Frame Generation Time (millisecond)', labelpad=15, color='#333333')

fig.tight_layout()
# Out:
# Mean: 47.68
# SD: 6.401006865243067

# %%
# save figure
fig.savefig('mobile_app_analytics/iphone12_mini_cert_info_qr_code_gen.png', dpi=600)
